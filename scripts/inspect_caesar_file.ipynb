# %%
import caesar

# %%
file = '/scratch/aspadawe/snapshots/Hyenas/L1/Simba_L0_Calibration/halo_1014/Groups/Caesar_halo_1014_151.hdf5'

# %%
obj = caesar.load(file)
# Out:
# yt : [INFO     ] 2026-01-03 17:09:47,794 Opening /scratch/aspadawe/snapshots/Hyenas/L1/Simba_L0_Calibration/halo_1014/Groups/Caesar_halo_1014_151.hdf5
# yt : [INFO     ] 2026-01-03 17:09:47,847 Found 11934 halos
# yt : [INFO     ] 2026-01-03 17:09:47,969 Found 1112 galaxies

# %%
halo_id = 0

# %%
halo = obj.halos[halo_id]

# %%
halo

# %%
halo.contamination
# Out:
# np.float64(3.681735694041332)

# %%
halo.virial_quantities['r200c']
# Out:
# unyt_quantity(518.7199707, 'kpccm')

# %%
halo.virial_quantities['r500c']
# Out:
# unyt_quantity(518.7199707, 'kpccm')

# %%
halo.virial_quantities['r2500c']
# Out:
# unyt_quantity(320.306427, 'kpccm')

# %%
halo.virial_quantities['m200c']
# Out:
# unyt_quantity(4.76037188e+13, 'Msun')

# %%
halo.virial_quantities['m500c']
# Out:
# unyt_quantity(4.76037188e+13, 'Msun')

# %%
halo.virial_quantities['m2500c']
# Out:
# unyt_quantity(4.41802356e+13, 'Msun')

# %%
halo.masses['gas']
# Out:
# unyt_quantity(2.27889894e+09, 'Msun')

# %%
halo.masses['total']
# Out:
# unyt_quantity(4.76021921e+13, 'Msun')
